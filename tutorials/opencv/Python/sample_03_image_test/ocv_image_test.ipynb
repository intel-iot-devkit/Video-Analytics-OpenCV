# %% [markdown]
# # OpenCV Tutorial Sample 3: ocv_image_test

# %% [markdown]
# [Sample 03](sample_03/ocv_image_test.py) is a sanity test that uses OpenCV to display an Image file. This test serves to ensure that OpenCV installation is working and validates the development environment. It also shows how to overlay text on an image.

# %% [markdown]
# First the Standard Python Shebang

# %%
#!/usr/bin/env python2

# %% [markdown]
# Next import print_function for Python 2/3 comptibility. This allows use of print like a function in Python 2.x

# %%
# Python 2/3 compatibility
from __future__ import print_function
# Allows use of print like a function in Python 2.x

# %% [markdown]
# Import Numpy and OpenCV Python modules

# %%
# Import Numpy and OpenCV Python modules
import numpy as np
import cv2

# %% [markdown]
# Load an image from file using the OpenCV [cv2.imread()](http://docs.opencv.org/3.0-last-rst/modules/imgcodecs/doc/reading_and_writing_images.html#cv2.imread) function.
# ```
# cv2.imread(filename[, flags]) -> retval
# ```
# Parameters:
#
#     filename – Name and path of file to be loaded.
#     flags –
#
# Flags:
#
#     Flags specify how the image should be read:
#
# ```
#  1 = cv2.IMREAD_COLOR - The Default flag, loads a color image. Any transparency data of image will be ignored.
#  0 = cv2.IMREAD_GRAYSCALE : Loads image in grayscale mode
# -1 = cv2.IMREAD_UNCHANGED : Loads image without any modifications including alpha channel
# ```

# %%
img = cv2.imread('intel-hq.jpg',1)

# %% [markdown]
# The color information for images loaded by OpenCV are in reverse order (BGR) and are stored as a numpy array.
#
# >Note: The following section between the lines, is only available in the interactive tutorial and not in the script.
#
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
print(type(img))
# Out:
# <type 'numpy.ndarray'>

# %%
print(img)
# Out:
# [[[147  95  54]
#   [140  90  44]
#   [156 108  60]
#   ...,
#   [165 132  93]
#   [161 127  91]
#   [153 119  83]]
#
#  [[142  93  45]
#   [142  94  46]
#   [139  96  47]
#   ...,
#   [160 126  90]
#   [156 122  86]
#   [148 114  78]]
#
#  [[136  91  40]
#   [136  96  44]
#   [116  80  34]
#   ...,
#   [153 119  83]
#   [148 113  79]
#   [141 106  72]]
#
#  ...,
#  [[180 177 192]
#   [178 175 190]
#   [177 174 189]
#   ...,
#   [199 198 214]
#   [200 199 215]
#   [199 197 216]]
#
#  [[179 176 191]
#   [180 177 192]
#   [179 176 191]
#   ...,
#   [197 196 212]
#   [198 196 215]
#   [200 198 217]]
#
#  [[178 175 190]
#   [180 177 192]
#   [181 178 193]
#   ...,
#   [194 192 211]
#   [195 193 212]
#   [199 197 216]]]

# %% [markdown]
# You can display the image in matplotlib which processes images in RGB format to see that OpenCV loads images in BGR format

# %%
from matplotlib import pyplot as plt
plt.imshow(img)
plt.show()

# %% [markdown]
# After conversion to RGB, the image properly displays. Here we use an OpenCV [cv2.cvtColor()](http://docs.opencv.org/3.0-last-rst/modules/imgproc/doc/miscellaneous_transformations.html#cv2.cvtColor) function to convert colors...

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)
plt.show()

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Next we overlay text on top of the image using the OpenCV [cv2.putText()](http://docs.opencv.org/3.0-last-rst/modules/imgproc/doc/drawing_functions.html#cv2.putText) function.

# %%
# Overlay text on the image using OpenCV
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, "OpenCV Version:",(10,100), font, 2,(255,255,255),2,cv2.LINE_AA)
cv2.putText(img, cv2.__version__,(525,100), font, 2,(255,255,255),2,cv2.LINE_AA)
# Out:
# array([[[147,  95,  54],
#         [140,  90,  44],
#         [156, 108,  60],
#         ...,
#         [165, 132,  93],
#         [161, 127,  91],
#         [153, 119,  83]],
#
#        [[142,  93,  45],
#         [142,  94,  46],
#         [139,  96,  47],
#         ...,
#         [160, 126,  90],
#         [156, 122,  86],
#         [148, 114,  78]],
#
#        [[136,  91,  40],
#         [136,  96,  44],
#         [116,  80,  34],
#         ...,
#         [153, 119,  83],
#         [148, 113,  79],
#         [141, 106,  72]],
#
#        ...,
#        [[180, 177, 192],
#         [178, 175, 190],
#         [177, 174, 189],
#         ...,
#         [199, 198, 214],
#         [200, 199, 215],
#         [199, 197, 216]],
#
#        [[179, 176, 191],
#         [180, 177, 192],
#         [179, 176, 191],
#         ...,
#         [197, 196, 212],
#         [198, 196, 215],
#         [200, 198, 217]],
#
#        [[178, 175, 190],
#         [180, 177, 192],
#         [181, 178, 193],
#         ...,
#         [194, 192, 211],
#         [195, 193, 212],
#         [199, 197, 216]]], dtype=uint8)

# %% [markdown]
# Now we create a GUI window to display the loaded image. We do this using the [cv2.namedWindow()](http://docs.opencv.org/3.0-last-rst/modules/highgui/doc/user_interface.html#cv2.namedWindow) function.
# It is not necessary to use this function to display the image but using this function allows for better control over GUI windows.
#
# >Note: Sometimes Jupyter notebook based interactive tutorials may not open a GUI window when run locally. In such cases, use the function cv2.startWindowThread() as shown below, before calling namedWindow function.
#
# ```
# cv2.startWindowThread()
# cv2.namedWindow('image', cv2.WINDOW_AUTOSIZE)
# ```
#
# An empty window will open until an image is displayed.

# %%
# Create a GUI window to display the image
cv2.namedWindow('Sample_03: Displaying an Image', cv2.WINDOW_AUTOSIZE)

# %% [markdown]
# Now we display the previously loaded image with the overlay text inside this window using the OpenCV
# [cv2.imshow()](http://docs.opencv.org/3.0-last-rst/modules/highgui/doc/user_interface.html#cv2.imshow) function.
#
# >Note: Since we are using an OpenCV function to display the image, there is no need for conversion from BGR to RGB. The image will not load until the event handler is called.

# %%
# Display the Image
cv2.imshow('Sample_03: Displaying an Image',img)

# %% [markdown]
# The cv2.imshow() function should be followed by the [cv2.waitKey()](http://docs.opencv.org/3.0-last-rst/modules/highgui/doc/user_interface.html#cv2.waitKey) which displays the image for the specified number of milliseconds. This function is also an event handler and can be bound to the keyboard as seen in our example.

# %%
# Exit on any keystroke
if cv2.waitKey(0):
    print('Exiting ...')
# Out:
# Exiting ...

# %% [markdown]
# Now we perform a cleanup and release all resources used using the function [cv2.destroyAllWindows()](http://docs.opencv.org/3.0-last-rst/modules/highgui/doc/user_interface.html#cv2.destroyAllWindows)

# %%
# Release resources used
cv2.destroyAllWindows()

# %% [markdown]
# Putting it all together with Exception handling:

# %%
try:
	# Load the image from file using OpenCV. The 1 means with color info
	example = cv2.imread('intel-hq.jpg',1)
	# Overlay text on the image using OpenCV
	font = cv2.FONT_HERSHEY_SIMPLEX
	cv2.putText(example, "OpenCV Version:",(10,100), font, 2,(255,255,255),2,cv2.LINE_AA)
	cv2.putText(example, cv2.__version__,(525,100), font, 2,(255,255,255),2,cv2.LINE_AA)

	# Create a GUI window to display the image
	cv2.namedWindow('Image display', cv2.WINDOW_AUTOSIZE)

	# Display the Image
	cv2.imshow('Image display',example)
	# Exit on any keystroke
	if cv2.waitKey(0):
		print('Exiting ...')

	# Release resources used
	cv2.destroyAllWindows()

except cv2.error as e:
	print('Error:')
# Out:
# Exiting ...
